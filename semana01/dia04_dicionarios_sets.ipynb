# %% [markdown]
# # 📚 Dia 4: Dicionários, Sets e Estruturas Aninhadas
#
# ## Objetivos
# - Criar e manipular dicionários (chave-valor)
# - Usar sets para dados únicos
# - Trabalhar com estruturas aninhadas
# - Representar balanço patrimonial como dados estruturados
#
# ## Data
# 12/11/2025
#
# ## Contexto
# Organizar dados financeiros complexos de forma clara e eficiente
#
# ---

# %%
# Balanço Patrimonial de uma empresa (valores em R$ mil)
balanco_patrimonial = {
    "empresa": "TechCorp S.A.",
    "data_referencia": "31/12/2024",
    "ativo": {
        "circulante": {
            "caixa": 150,
            "contas_receber": 200,
            "estoques": 100,
            "outros": 50
        },
        "nao_circulante": {
            "investimentos": 80,
            "imobilizado": 180,
            "intangivel": 40
        }
    },
    "passivo": {
        "circulante": {
            "fornecedores": 120,
            "emprestimos_curto": 80,
            "impostos": 50
        },
        "nao_circulante": {
            "emprestimos_longo": 100,
            "outros": 50
        }
    }
}

print("=" * 70)
print(f"BALANÇO PATRIMONIAL - {balanco_patrimonial['empresa']}")
print(f"Data: {balanco_patrimonial['data_referencia']}")
print("=" * 70)

# CALCULAR TOTAIS DO ATIVO
ativo_circulante = sum(balanco_patrimonial["ativo"]["circulante"].values())
ativo_nao_circulante = sum(balanco_patrimonial["ativo"]["nao_circulante"].values())
ativo_total = ativo_circulante + ativo_nao_circulante

print(f"\n📊 ATIVO")
print(f"{'Ativo Circulante':30s} R$ {ativo_circulante:>10,.0f}k")

# Detalhar ativo circulante
for conta, valor in balanco_patrimonial["ativo"]["circulante"].items():
    print(f"  • {conta.replace('_', ' ').title():28s} R$ {valor:>10,.0f}k")

print(f"\n{'Ativo Não Circulante':30s} R$ {ativo_nao_circulante:>10,.0f}k")

# Detalhar ativo não circulante
for conta, valor in balanco_patrimonial["ativo"]["nao_circulante"].items():
    print(f"  • {conta.replace('_', ' ').title():28s} R$ {valor:>10,.0f}k")

print(f"{'-' * 43}")
print(f"{'ATIVO TOTAL':30s} R$ {ativo_total:>10,.0f}k")

# CALCULAR TOTAIS DO PASSIVO
passivo_circulante = sum(balanco_patrimonial["passivo"]["circulante"].values())
passivo_nao_circulante = sum(balanco_patrimonial["passivo"]["nao_circulante"].values())
passivo_total = passivo_circulante + passivo_nao_circulante

print(f"\n📊 PASSIVO")
print(f"{'Passivo Circulante':30s} R$ {passivo_circulante:>10,.0f}k")

for conta, valor in balanco_patrimonial["passivo"]["circulante"].items():
    print(f"  • {conta.replace('_', ' ').title():28s} R$ {valor:>10,.0f}k")

print(f"\n{'Passivo Não Circulante':30s} R$ {passivo_nao_circulante:>10,.0f}k")

for conta, valor in balanco_patrimonial["passivo"]["nao_circulante"].items():
    print(f"  • {conta.replace('_', ' ').title():28s} R$ {valor:>10,.0f}k")

print(f"{'-' * 43}")
print(f"{'PASSIVO TOTAL':30s} R$ {passivo_total:>10,.0f}k")

# PATRIMÔNIO LÍQUIDO
patrimonio_liquido = ativo_total - passivo_total

print(f"\n{'PATRIMÔNIO LÍQUIDO':30s} R$ {patrimonio_liquido:>10,.0f}k")
print("=" * 70)

# INDICADORES
liquidez_corrente = ativo_circulante / passivo_circulante
endividamento = passivo_total / ativo_total

print(f"\n📈 INDICADORES FINANCEIROS")
print(f"Liquidez Corrente:   {liquidez_corrente:.2f}")
print(f"Índice Endividamento: {endividamento:.2%}")
print("=" * 70)
# Out:
# ======================================================================
# BALANÇO PATRIMONIAL - TechCorp S.A.
# Data: 31/12/2024
# ======================================================================
#
# 📊 ATIVO
# Ativo Circulante               R$        500k
#   • Caixa                        R$        150k
#   • Contas Receber               R$        200k
#   • Estoques                     R$        100k
#   • Outros                       R$         50k
#
# Ativo Não Circulante           R$        300k
#   • Investimentos                R$         80k
#   • Imobilizado                  R$        180k
#   • Intangivel                   R$         40k
# -------------------------------------------
# ATIVO TOTAL                    R$        800k
#
# 📊 PASSIVO
# Passivo Circulante             R$        250k
#   • Fornecedores                 R$        120k
#   • Emprestimos Curto            R$         80k
#   • Impostos                     R$         50k
#
# Passivo Não Circulante         R$        150k
#   • Emprestimos Longo            R$        100k
#   • Outros                       R$         50k
# -------------------------------------------
# PASSIVO TOTAL                  R$        400k
#
# PATRIMÔNIO LÍQUIDO             R$        400k
# ======================================================================
#
# 📈 INDICADORES FINANCEIROS
# Liquidez Corrente:   2.00
# Índice Endividamento: 50.00%
# ======================================================================

# %%
# Exemplo passo a passo

# 1. Dicionário simples (1 nível)
produto = {
    "nome": "Notebook",
    "preco": 3500,
    "estoque": 10
}

print("1. Dicionário simples:")
print(f"Nome: {produto['nome']}")
print(f"Preço: R$ {produto['preco']:,.2f}")

# 2. Dicionário aninhado (2 níveis)
loja = {
    "nome": "TechStore",
    "produtos": {
        "notebook": 3500,
        "mouse": 50,
        "teclado": 150
    }
}

print("\n2. Dicionário aninhado:")
print(f"Preço do mouse: R$ {loja['produtos']['mouse']:.2f}")

# 3. Somar valores
total_estoque = sum(loja["produtos"].values())
print(f"Valor total estoque: R$ {total_estoque:,.2f}")

# 4. Iterar
print("\n3. Lista de produtos:")
for produto, preco in loja["produtos"].items():
    print(f"  • {produto.title():15s} R$ {preco:>8,.2f}")
# Out:
# 1. Dicionário simples:
# Nome: Notebook
# Preço: R$ 3,500.00
#
# 2. Dicionário aninhado:
# Preço do mouse: R$ 50.00
# Valor total estoque: R$ 3,700.00
#
# 3. Lista de produtos:
#   • Notebook        R$ 3,500.00
#   • Mouse           R$    50.00
#   • Teclado         R$   150.00

# %% [markdown]
# ## 💼 EXERCÍCIO 1: Sistema de Cadastro de Empresas
#
# **Objetivo:** Trabalhar com lista de dicionários (estrutura muito comum!)
#
# **Dados:** 3 empresas do setor tecnológico
#
# **Tarefas:**
# 1. Calcular indicadores de cada empresa
# 2. Identificar empresa mais lucrativa
# 3. Calcular médias do setor
# 4. Filtrar empresas rentáveis
# 5. Criar ranking por margem líquida
#
# ---

# %%
# Base de dados: 3 empresas
empresas = [
    {
        "nome": "TechCorp",
        "receita": 1500000,
        "despesas": 1200000,
        "funcionarios": 42,
        "setor": "Software"
    },
    {
        "nome": "DataPro",
        "receita": 2200000,
        "despesas": 1850000,
        "funcionarios": 65,
        "setor": "Dados"
    },
    {
        "nome": "CloudNet",
        "receita": 950000,
        "despesas": 880000,
        "funcionarios": 28,
        "setor": "Cloud"
    }
]

print("=" * 75)
print("ANÁLISE SETORIAL - EMPRESAS DE TECNOLOGIA")
print("=" * 75)

# 1. CALCULAR INDICADORES PARA CADA EMPRESA
for empresa in empresas:
    # Calcular lucro
    empresa["lucro"] = empresa["receita"] - empresa["despesas"]
    
    # Calcular margem líquida (%)
    empresa["margem"] = (empresa["lucro"] / empresa["receita"]) * 100
    
    # Calcular receita por funcionário
    empresa["receita_per_capita"] = empresa["receita"] / empresa["funcionarios"]

# 2. EXIBIR TABELA
print(f"\n{'Empresa':^12} | {'Receita':>12} | {'Lucro':>12} | {'Margem':>8} | {'Funcs':>6} | {'R$/Func':>12}")
print("-" * 75)

for emp in empresas:
    print(f"{emp['nome']:^12} | R$ {emp['receita']:>9,.0f} | R$ {emp['lucro']:>9,.0f} | "
          f"{emp['margem']:>6.2f}% | {emp['funcionarios']:>6} | R$ {emp['receita_per_capita']:>9,.0f}")

print("-" * 75)

# 3. IDENTIFICAR EMPRESA MAIS LUCRATIVA
empresa_top_lucro = max(empresas, key=lambda e: e["lucro"])
print(f"\n🏆 Maior lucro absoluto:  {empresa_top_lucro['nome']} "
      f"(R$ {empresa_top_lucro['lucro']:,.2f})")

# 4. IDENTIFICAR MELHOR MARGEM
empresa_top_margem = max(empresas, key=lambda e: e["margem"])
print(f"📊 Melhor margem líquida: {empresa_top_margem['nome']} "
      f"({empresa_top_margem['margem']:.2f}%)")

# 5. IDENTIFICAR MAIS EFICIENTE (receita por funcionário)
empresa_top_eficiencia = max(empresas, key=lambda e: e["receita_per_capita"])
print(f"⚡ Mais eficiente:        {empresa_top_eficiencia['nome']} "
      f"(R$ {empresa_top_eficiencia['receita_per_capita']:,.0f}/func)")

# 6. CALCULAR MÉDIAS DO SETOR
total_receita = sum(emp["receita"] for emp in empresas)
total_lucro = sum(emp["lucro"] for emp in empresas)
media_margem = sum(emp["margem"] for emp in empresas) / len(empresas)
total_funcionarios = sum(emp["funcionarios"] for emp in empresas)

print(f"\n📈 CONSOLIDADO DO SETOR:")
print(f"Receita total:       R$ {total_receita:>12,.2f}")
print(f"Lucro total:         R$ {total_lucro:>12,.2f}")
print(f"Margem média:        {media_margem:>15.2f}%")
print(f"Total funcionários:  {total_funcionarios:>16}")

# 7. FILTRAR EMPRESAS COM MARGEM > 15%
empresas_rentaveis = [emp for emp in empresas if emp["margem"] > 15]

print(f"\n✅ Empresas com margem > 15% ({len(empresas_rentaveis)}):")
for emp in empresas_rentaveis:
    print(f"  → {emp['nome']}: {emp['margem']:.2f}%")

# 8. ORDENAR POR MARGEM (ranking)
ranking = sorted(empresas, key=lambda e: e["margem"], reverse=True)

print(f"\n🏅 RANKING POR MARGEM LÍQUIDA:")
for i, emp in enumerate(ranking, 1):
    emoji = "🥇" if i == 1 else "🥈" if i == 2 else "🥉"
    print(f"{emoji} {i}º lugar: {emp['nome']} - {emp['margem']:.2f}%")

print("=" * 75)
# Out:
# ===========================================================================
# ANÁLISE SETORIAL - EMPRESAS DE TECNOLOGIA
# ===========================================================================
#
#   Empresa    |      Receita |        Lucro |   Margem |  Funcs |      R$/Func
# ---------------------------------------------------------------------------
#   TechCorp   | R$ 1,500,000 | R$   300,000 |  20.00% |     42 | R$    35,714
#   DataPro    | R$ 2,200,000 | R$   350,000 |  15.91% |     65 | R$    33,846
#   CloudNet   | R$   950,000 | R$    70,000 |   7.37% |     28 | R$    33,929
# ---------------------------------------------------------------------------
#
# 🏆 Maior lucro absoluto:  DataPro (R$ 350,000.00)
# 📊 Melhor margem líquida: TechCorp (20.00%)
# ⚡ Mais eficiente:        TechCorp (R$ 35,714/func)
#
# 📈 CONSOLIDADO DO SETOR:
# Receita total:       R$ 4,650,000.00
# Lucro total:         R$   720,000.00
# Margem média:                  14.43%
# Total funcionários:               135
#
# ✅ Empresas com margem > 15% (2):
#   → TechCorp: 20.00%
#   → DataPro: 15.91%
#
# 🏅 RANKING POR MARGEM LÍQUIDA:
# 🥇 1º lugar: TechCorp - 20.00%
# 🥈 2º lugar: DataPro - 15.91%
# 🥉 3º lugar: CloudNet - 7.37%
# ===========================================================================

# %%
# Dados de exemplo
empresas = [
    {"nome": "Alpha", "receita": 1000, "despesas": 800},
    {"nome": "Beta", "receita": 1500, "despesas": 1200},
    {"nome": "Gamma", "receita": 800, "despesas": 750},
    {"nome": "Delta", "receita": 2000, "despesas": 1900}
]

print("="*60)
print("EXEMPLOS DE LIST COMPREHENSION COM DICIONÁRIOS")
print("="*60)

# 1. Extrair nomes
nomes = [emp["nome"] for emp in empresas]
print(f"\n1. Nomes: {nomes}")

# 2. Extrair receitas
receitas = [emp["receita"] for emp in empresas]
print(f"\n2. Receitas: {receitas}")

# 3. Calcular lucros
lucros = [emp["receita"] - emp["despesas"] for emp in empresas]
print(f"\n3. Lucros: {lucros}")

# 4. Filtrar empresas com receita > 1000
grandes = [emp for emp in empresas if emp["receita"] > 1000]
print(f"\n4. Empresas grandes:")
for emp in grandes:
    print(f"   → {emp['nome']}: R$ {emp['receita']}")

# 5. Nomes de empresas lucrativas (lucro > 200)
lucrativas = [
    emp["nome"] 
    for emp in empresas 
    if (emp["receita"] - emp["despesas"]) > 200
]
print(f"\n5. Empresas lucrativas: {lucrativas}")

# 6. Total de receitas (com generator)
total_receita = sum(emp["receita"] for emp in empresas)
print(f"\n6. Receita total: R$ {total_receita:,.2f}")

# 7. Margem de cada empresa
margens = [
    (emp["receita"] - emp["despesas"]) / emp["receita"] * 100
    for emp in empresas
]
print(f"\n7. Margens: {[f'{m:.1f}%' for m in margens]}")

# 8. Criar dicionários resumidos
resumo = [
    {"nome": emp["nome"], "lucro": emp["receita"] - emp["despesas"]}
    for emp in empresas
]
print(f"\n8. Resumo:")
for item in resumo:
    print(f"   {item['nome']}: R$ {item['lucro']}")

print("="*60)
# Out:
# ============================================================
# EXEMPLOS DE LIST COMPREHENSION COM DICIONÁRIOS
# ============================================================
#
# 1. Nomes: ['Alpha', 'Beta', 'Gamma', 'Delta']
#
# 2. Receitas: [1000, 1500, 800, 2000]
#
# 3. Lucros: [200, 300, 50, 100]
#
# 4. Empresas grandes:
#    → Beta: R$ 1500
#    → Delta: R$ 2000
#
# 5. Empresas lucrativas: ['Beta']
#
# 6. Receita total: R$ 5,300.00
#
# 7. Margens: ['20.0%', '20.0%', '6.2%', '5.0%']
#
# 8. Resumo:
#    Alpha: R$ 200
#    Beta: R$ 300
#    Gamma: R$ 50
#    Delta: R$ 100
# ============================================================

# %% [markdown]
# ## 🔢 EXERCÍCIO 2: Análise de Clientes com Sets
#
# **Objetivo:** Usar sets para encontrar padrões únicos e intersecções
#
# **Contexto:** Analisar base de clientes de 2024 vs 2025
#
# **Tarefas:**
# 1. Identificar clientes recorrentes (presentes nos 2 anos)
# 2. Identificar clientes que saíram (só em 2024)
# 3. Identificar clientes novos (só em 2025)
# 4. Calcular taxa de retenção
# 5. Analisar produtos únicos comprados
#
# ---

# %%
# Base de clientes e transações
clientes_2024 = {
    "João Silva", "Maria Santos", "Pedro Costa", "Ana Oliveira",
    "Carlos Souza", "Lucia Lima", "Roberto Alves"
}

clientes_2025 = {
    "Maria Santos", "Pedro Costa", "Ana Oliveira", "Carlos Souza",
    "Fernando Dias", "Beatriz Rocha", "Gabriel Martins", "Lucia Lima"
}

# Produtos vendidos em cada ano
produtos_2024 = {
    "Notebook", "Mouse", "Teclado", "Monitor", "Webcam", "Headset"
}

produtos_2025 = {
    "Notebook", "Mouse", "Teclado", "Monitor", "SSD", "RAM", "Mousepad"
}

print("=" * 70)
print("ANÁLISE DE RETENÇÃO DE CLIENTES - 2024 vs 2025")
print("=" * 70)

# ESTATÍSTICAS BÁSICAS
print(f"\n📊 ESTATÍSTICAS:")
print(f"Clientes em 2024:  {len(clientes_2024)}")
print(f"Clientes em 2025:  {len(clientes_2025)}")

# 1. CLIENTES RECORRENTES (interseção)
recorrentes = clientes_2024 & clientes_2025
# OU: recorrentes = clientes_2024.intersection(clientes_2025)

print(f"\n🟢 CLIENTES RECORRENTES ({len(recorrentes)}):")
for cliente in sorted(recorrentes):
    print(f"  ✓ {cliente}")

# 2. CLIENTES QUE SAÍRAM (diferença: em 2024 mas não em 2025)
saiu = clientes_2024 - clientes_2025
# OU: saiu = clientes_2024.difference(clientes_2025)

print(f"\n🔴 CLIENTES QUE SAÍRAM ({len(saiu)}):")
for cliente in sorted(saiu):
    print(f"  ✗ {cliente}")

# 3. CLIENTES NOVOS (diferença: em 2025 mas não em 2024)
novos = clientes_2025 - clientes_2024

print(f"\n🟡 CLIENTES NOVOS ({len(novos)}):")
for cliente in sorted(novos):
    print(f"  → {cliente}")

# 4. TODOS OS CLIENTES (união)
todos = clientes_2024 | clientes_2025
# OU: todos = clientes_2024.union(clientes_2025)

print(f"\n📋 TOTAL DE CLIENTES ÚNICOS (2024+2025): {len(todos)}")

# 5. TAXA DE RETENÇÃO
taxa_retencao = (len(recorrentes) / len(clientes_2024)) * 100
print(f"\n📈 MÉTRICAS DE RETENÇÃO:")
print(f"Taxa de retenção:        {taxa_retencao:>6.2f}%")
print(f"Taxa de perda (churn):   {100 - taxa_retencao:>6.2f}%")
print(f"Crescimento líquido:     {len(clientes_2025) - len(clientes_2024):>+6} clientes")

# ANÁLISE DE PRODUTOS
print("\n" + "=" * 70)
print("ANÁLISE DE PRODUTOS")
print("=" * 70)

# Produtos que continuaram
produtos_continuaram = produtos_2024 & produtos_2025
print(f"\n✅ Produtos mantidos ({len(produtos_continuaram)}):")
print(f"   {', '.join(sorted(produtos_continuaram))}")

# Produtos descontinuados
descontinuados = produtos_2024 - produtos_2025
print(f"\n❌ Produtos descontinuados ({len(descontinuados)}):")
print(f"   {', '.join(sorted(descontinuados))}")

# Produtos novos no catálogo
produtos_novos = produtos_2025 - produtos_2024
print(f"\n🆕 Novos produtos ({len(produtos_novos)}):")
print(f"   {', '.join(sorted(produtos_novos))}")

# Todos os produtos já vendidos
catalogo_completo = produtos_2024 | produtos_2025
print(f"\n📦 Catálogo completo histórico ({len(catalogo_completo)} produtos):")
for produto in sorted(catalogo_completo):
    if produto in produtos_2024 and produto in produtos_2025:
        status = "🟢"
    elif produto in produtos_2024:
        status = "🔴"
    else:
        status = "🟡"
    print(f"   {status} {produto}")

# INSIGHTS
print("\n" + "=" * 70)
print("💡 INSIGHTS:")
print("=" * 70)

if taxa_retencao > 70:
    print("✅ Excelente retenção de clientes!")
elif taxa_retencao > 50:
    print("⚠️  Retenção moderada. Considere programa de fidelidade.")
else:
    print("🔴 Atenção! Alta taxa de perda de clientes.")

if len(novos) > len(saiu):
    print("✅ Crescimento positivo da base de clientes!")
elif len(novos) == len(saiu):
    print("⚠️  Base estagnada. Precisa atrair mais clientes.")
else:
    print("🔴 Base de clientes encolhendo!")

print("=" * 70)
# Out:
# ======================================================================
# ANÁLISE DE RETENÇÃO DE CLIENTES - 2024 vs 2025
# ======================================================================
#
# 📊 ESTATÍSTICAS:
# Clientes em 2024:  7
# Clientes em 2025:  8
#
# 🟢 CLIENTES RECORRENTES (5):
#   ✓ Ana Oliveira
#   ✓ Carlos Souza
#   ✓ Lucia Lima
#   ✓ Maria Santos
#   ✓ Pedro Costa
#
# 🔴 CLIENTES QUE SAÍRAM (2):
#   ✗ João Silva
#   ✗ Roberto Alves
#
# 🟡 CLIENTES NOVOS (3):
#   → Beatriz Rocha
#   → Fernando Dias
#   → Gabriel Martins
#
# 📋 TOTAL DE CLIENTES ÚNICOS (2024+2025): 10
#
# 📈 MÉTRICAS DE RETENÇÃO:
# Taxa de retenção:         71.43%
# Taxa de perda (churn):    28.57%
# Crescimento líquido:         +1 clientes
#
# ======================================================================
# ANÁLISE DE PRODUTOS
# ======================================================================
#
# ✅ Produtos mantidos (4):
#    Monitor, Mouse, Notebook, Teclado
#
# ❌ Produtos descontinuados (2):
#    Headset, Webcam
#
# 🆕 Novos produtos (3):
#    Mousepad, RAM, SSD
#
# 📦 Catálogo completo histórico (9 produtos):
#    🔴 Headset
#    🟢 Monitor
#    🟢 Mouse
#    🟡 Mousepad
#    🟢 Notebook
#    🟡 RAM
#    🟡 SSD
#    🟢 Teclado
#    🔴 Webcam
#
# ======================================================================
# 💡 INSIGHTS:
# ======================================================================
# ✅ Excelente retenção de clientes!
# ✅ Crescimento positivo da base de clientes!
# ======================================================================

# %%
# Demonstração de operações com sets

vendas_janeiro = {"Produto A", "Produto B", "Produto C"}
vendas_fevereiro = {"Produto B", "Produto C", "Produto D"}

print("OPERAÇÕES COM SETS:\n")

print(f"Janeiro:    {vendas_janeiro}")
print(f"Fevereiro:  {vendas_fevereiro}")

print(f"\n& (interseção):  {vendas_janeiro & vendas_fevereiro}")
print(f"| (união):        {vendas_janeiro | vendas_fevereiro}")
print(f"- (diferença):   {vendas_janeiro - vendas_fevereiro}")
print(f"^ (simétrica):   {vendas_janeiro ^ vendas_fevereiro}")
# Out:
# OPERAÇÕES COM SETS:
#
# Janeiro:    {'Produto B', 'Produto A', 'Produto C'}
# Fevereiro:  {'Produto B', 'Produto D', 'Produto C'}
#
# & (interseção):  {'Produto B', 'Produto C'}
# | (união):        {'Produto A', 'Produto D', 'Produto B', 'Produto C'}
# - (diferença):   {'Produto A'}
# ^ (simétrica):   {'Produto A', 'Produto D'}

# %% [markdown]
# ## 📊 EXERCÍCIO 3: DRE Comparativa de 3 Empresas
#
# **Objetivo:** Trabalhar com estruturas complexas (lista de dicionários aninhados)
#
# **Contexto:** Análise de DRE de múltiplas empresas para comparação setorial
#
# **Tarefas:**
# 1. Calcular todos os indicadores da DRE
# 2. Identificar empresa mais rentável
# 3. Calcular médias do setor
# 4. Criar ranking por EBITDA
# 5. Análise horizontal (crescimento)
#
# ---

# %%
# Base de dados: DRE de 3 empresas (estrutura aninhada complexa)
empresas_dre = [
    {
        "nome": "TechCorp",
        "ano": 2024,
        "dre": {
            "receita_bruta": 5000000,
            "deducoes": {
                "impostos": 750000,
                "devolucoes": 250000
            },
            "custos": {
                "cmv": 2000000
            },
            "despesas": {
                "vendas": 400000,
                "administrativas": 300000,
                "financeiras": 150000
            }
        }
    },
    {
        "nome": "DataPro",
        "ano": 2024,
        "dre": {
            "receita_bruta": 7200000,
            "deducoes": {
                "impostos": 1080000,
                "devolucoes": 360000
            },
            "custos": {
                "cmv": 3000000
            },
            "despesas": {
                "vendas": 600000,
                "administrativas": 450000,
                "financeiras": 200000
            }
        }
    },
    {
        "nome": "CloudNet",
        "ano": 2024,
        "dre": {
            "receita_bruta": 3800000,
            "deducoes": {
                "impostos": 570000,
                "devolucoes": 190000
            },
            "custos": {
                "cmv": 1600000
            },
            "despesas": {
                "vendas": 280000,
                "administrativas": 220000,
                "financeiras": 100000
            }
        }
    }
]

print("=" * 80)
print("ANÁLISE COMPARATIVA DE DRE - SETOR TECNOLOGIA 2024")
print("=" * 80)

# CALCULAR INDICADORES PARA CADA EMPRESA
for empresa in empresas_dre:
    dre = empresa["dre"]
    
    # 1. Receita Líquida = Receita Bruta - Deduções
    total_deducoes = sum(dre["deducoes"].values())
    dre["receita_liquida"] = dre["receita_bruta"] - total_deducoes
    
    # 2. Lucro Bruto = Receita Líquida - CMV
    dre["lucro_bruto"] = dre["receita_liquida"] - dre["custos"]["cmv"]
    
    # 3. Despesas Operacionais = Vendas + Admin
    dre["despesas_operacionais"] = (dre["despesas"]["vendas"] + 
                                     dre["despesas"]["administrativas"])
    
    # 4. EBITDA = Lucro Bruto - Despesas Operacionais
    dre["ebitda"] = dre["lucro_bruto"] - dre["despesas_operacionais"]
    
    # 5. Lucro Líquido = EBITDA - Despesas Financeiras
    dre["lucro_liquido"] = dre["ebitda"] - dre["despesas"]["financeiras"]
    
    # 6. Margens (%)
    dre["margem_bruta"] = (dre["lucro_bruto"] / dre["receita_liquida"]) * 100
    dre["margem_ebitda"] = (dre["ebitda"] / dre["receita_liquida"]) * 100
    dre["margem_liquida"] = (dre["lucro_liquido"] / dre["receita_liquida"]) * 100

# EXIBIR DRE DE CADA EMPRESA
for empresa in empresas_dre:
    nome = empresa["nome"]
    dre = empresa["dre"]
    
    print(f"\n{'=' * 80}")
    print(f"DRE - {nome.upper()}")
    print(f"{'=' * 80}")
    
    print(f"\nReceita Bruta                      R$ {dre['receita_bruta']:>15,.2f}")
    print(f"(-) Impostos sobre vendas          R$ {dre['deducoes']['impostos']:>15,.2f}")
    print(f"(-) Devoluções                     R$ {dre['deducoes']['devolucoes']:>15,.2f}")
    print(f"{'-' * 80}")
    print(f"Receita Líquida                    R$ {dre['receita_liquida']:>15,.2f}")
    
    print(f"\n(-) Custo Mercadoria Vendida       R$ {dre['custos']['cmv']:>15,.2f}")
    print(f"{'-' * 80}")
    print(f"Lucro Bruto                        R$ {dre['lucro_bruto']:>15,.2f}  "
          f"({dre['margem_bruta']:.2f}%)")
    
    print(f"\n(-) Despesas com Vendas            R$ {dre['despesas']['vendas']:>15,.2f}")
    print(f"(-) Despesas Administrativas       R$ {dre['despesas']['administrativas']:>15,.2f}")
    print(f"{'-' * 80}")
    print(f"EBITDA                             R$ {dre['ebitda']:>15,.2f}  "
          f"({dre['margem_ebitda']:.2f}%)")
    
    print(f"\n(-) Despesas Financeiras           R$ {dre['despesas']['financeiras']:>15,.2f}")
    print(f"{'=' * 80}")
    print(f"LUCRO LÍQUIDO                      R$ {dre['lucro_liquido']:>15,.2f}  "
          f"({dre['margem_liquida']:.2f}%)")

# ANÁLISE COMPARATIVA
print(f"\n\n{'=' * 80}")
print("ANÁLISE COMPARATIVA - RESUMO EXECUTIVO")
print(f"{'=' * 80}")

print(f"\n{'Empresa':^12} | {'Rec. Líq.':>12} | {'EBITDA':>12} | {'Lucro Líq.':>12} | "
      f"{'Mg Bruta':>8} | {'Mg EBITDA':>9} | {'Mg Líq.':>7}")
print("-" * 80)

for emp in empresas_dre:
    dre = emp["dre"]
    print(f"{emp['nome']:^12} | R$ {dre['receita_liquida']:>9,.0f} | "
          f"R$ {dre['ebitda']:>9,.0f} | R$ {dre['lucro_liquido']:>9,.0f} | "
          f"{dre['margem_bruta']:>6.2f}% | {dre['margem_ebitda']:>7.2f}% | "
          f"{dre['margem_liquida']:>5.2f}%")

print("-" * 80)

# IDENTIFICAR DESTAQUES
empresa_maior_receita = max(empresas_dre, key=lambda e: e["dre"]["receita_liquida"])
empresa_maior_lucro = max(empresas_dre, key=lambda e: e["dre"]["lucro_liquido"])
empresa_melhor_margem = max(empresas_dre, key=lambda e: e["dre"]["margem_liquida"])
empresa_maior_ebitda = max(empresas_dre, key=lambda e: e["dre"]["ebitda"])

print(f"\n🏆 DESTAQUES:")
print(f"Maior Receita Líquida:  {empresa_maior_receita['nome']} "
      f"(R$ {empresa_maior_receita['dre']['receita_liquida']:,.2f})")
print(f"Maior Lucro Líquido:    {empresa_maior_lucro['nome']} "
      f"(R$ {empresa_maior_lucro['dre']['lucro_liquido']:,.2f})")
print(f"Melhor Margem Líquida:  {empresa_melhor_margem['nome']} "
      f"({empresa_melhor_margem['dre']['margem_liquida']:.2f}%)")
print(f"Maior EBITDA:           {empresa_maior_ebitda['nome']} "
      f"(R$ {empresa_maior_ebitda['dre']['ebitda']:,.2f})")

# MÉDIAS DO SETOR
total_receita = sum(e["dre"]["receita_liquida"] for e in empresas_dre)
total_ebitda = sum(e["dre"]["ebitda"] for e in empresas_dre)
total_lucro = sum(e["dre"]["lucro_liquido"] for e in empresas_dre)
media_margem_bruta = sum(e["dre"]["margem_bruta"] for e in empresas_dre) / len(empresas_dre)
media_margem_liquida = sum(e["dre"]["margem_liquida"] for e in empresas_dre) / len(empresas_dre)

print(f"\n📊 MÉDIAS DO SETOR:")
print(f"Receita Líquida Total:    R$ {total_receita:>12,.2f}")
print(f"EBITDA Total:             R$ {total_ebitda:>12,.2f}")
print(f"Lucro Líquido Total:      R$ {total_lucro:>12,.2f}")
print(f"Margem Bruta Média:       {media_margem_bruta:>15.2f}%")
print(f"Margem Líquida Média:     {media_margem_liquida:>15.2f}%")

# RANKING POR EBITDA
ranking_ebitda = sorted(empresas_dre, key=lambda e: e["dre"]["ebitda"], reverse=True)

print(f"\n🏅 RANKING POR EBITDA:")
for i, emp in enumerate(ranking_ebitda, 1):
    emoji = "🥇" if i == 1 else "🥈" if i == 2 else "🥉"
    print(f"{emoji} {i}º - {emp['nome']:12s} R$ {emp['dre']['ebitda']:>12,.2f}  "
          f"({emp['dre']['margem_ebitda']:.2f}%)")

# INSIGHTS
print(f"\n{'=' * 80}")
print("💡 INSIGHTS ESTRATÉGICOS:")
print(f"{'=' * 80}")

# Comparar com médias
for emp in empresas_dre:
    print(f"\n{emp['nome']}:")
    
    if emp["dre"]["margem_liquida"] > media_margem_liquida:
        print(f"  ✅ Margem líquida ACIMA da média do setor "
              f"({emp['dre']['margem_liquida']:.2f}% vs {media_margem_liquida:.2f}%)")
    else:
        print(f"  ⚠️  Margem líquida ABAIXO da média do setor "
              f"({emp['dre']['margem_liquida']:.2f}% vs {media_margem_liquida:.2f}%)")
    
    if emp["dre"]["margem_ebitda"] > 20:
        print(f"  ✅ EBITDA saudável ({emp['dre']['margem_ebitda']:.2f}%)")
    elif emp["dre"]["margem_ebitda"] > 15:
        print(f"  ⚠️  EBITDA moderado ({emp['dre']['margem_ebitda']:.2f}%)")
    else:
        print(f"  🔴 EBITDA preocupante ({emp['dre']['margem_ebitda']:.2f}%)")

print(f"{'=' * 80}")
# Out:
# ================================================================================
# ANÁLISE COMPARATIVA DE DRE - SETOR TECNOLOGIA 2024
# ================================================================================
#
# ================================================================================
# DRE - TECHCORP
# ================================================================================
#
# Receita Bruta                      R$    5,000,000.00
# (-) Impostos sobre vendas          R$      750,000.00
# (-) Devoluções                     R$      250,000.00
# --------------------------------------------------------------------------------
# Receita Líquida                    R$    4,000,000.00
#
# (-) Custo Mercadoria Vendida       R$    2,000,000.00
# --------------------------------------------------------------------------------
# Lucro Bruto                        R$    2,000,000.00  (50.00%)
#
# (-) Despesas com Vendas            R$      400,000.00
# (-) Despesas Administrativas       R$      300,000.00
# --------------------------------------------------------------------------------
# EBITDA                             R$    1,300,000.00  (32.50%)
#
# (-) Despesas Financeiras           R$      150,000.00
# ================================================================================
# LUCRO LÍQUIDO                      R$    1,150,000.00  (28.75%)
#
# ================================================================================
# DRE - DATAPRO
# ================================================================================
#
# Receita Bruta                      R$    7,200,000.00
# (-) Impostos sobre vendas          R$    1,080,000.00
# (-) Devoluções                     R$      360,000.00
# --------------------------------------------------------------------------------
# Receita Líquida                    R$    5,760,000.00
#
# (-) Custo Mercadoria Vendida       R$    3,000,000.00
# --------------------------------------------------------------------------------
# Lucro Bruto                        R$    2,760,000.00  (47.92%)
#
# (-) Despesas com Vendas            R$      600,000.00
# (-) Despesas Administrativas       R$      450,000.00
# --------------------------------------------------------------------------------
# EBITDA                             R$    1,710,000.00  (29.69%)
#
# (-) Despesas Financeiras           R$      200,000.00
# ================================================================================
# LUCRO LÍQUIDO                      R$    1,510,000.00  (26.22%)
#
# ================================================================================
# DRE - CLOUDNET
# ================================================================================
#
# Receita Bruta                      R$    3,800,000.00
# (-) Impostos sobre vendas          R$      570,000.00
# (-) Devoluções                     R$      190,000.00
# --------------------------------------------------------------------------------
# Receita Líquida                    R$    3,040,000.00
#
# (-) Custo Mercadoria Vendida       R$    1,600,000.00
# --------------------------------------------------------------------------------
# Lucro Bruto                        R$    1,440,000.00  (47.37%)
#
# (-) Despesas com Vendas            R$      280,000.00
# (-) Despesas Administrativas       R$      220,000.00
# --------------------------------------------------------------------------------
# EBITDA                             R$      940,000.00  (30.92%)
#
# (-) Despesas Financeiras           R$      100,000.00
# ================================================================================
# LUCRO LÍQUIDO                      R$      840,000.00  (27.63%)
#
#
# ================================================================================
# ANÁLISE COMPARATIVA - RESUMO EXECUTIVO
# ================================================================================
#
#   Empresa    |    Rec. Líq. |       EBITDA |   Lucro Líq. | Mg Bruta | Mg EBITDA | Mg Líq.
# --------------------------------------------------------------------------------
#   TechCorp   | R$ 4,000,000 | R$ 1,300,000 | R$ 1,150,000 |  50.00% |   32.50% | 28.75%
#   DataPro    | R$ 5,760,000 | R$ 1,710,000 | R$ 1,510,000 |  47.92% |   29.69% | 26.22%
#   CloudNet   | R$ 3,040,000 | R$   940,000 | R$   840,000 |  47.37% |   30.92% | 27.63%
# --------------------------------------------------------------------------------
#
# 🏆 DESTAQUES:
# Maior Receita Líquida:  DataPro (R$ 5,760,000.00)
# Maior Lucro Líquido:    DataPro (R$ 1,510,000.00)
# Melhor Margem Líquida:  TechCorp (28.75%)
# Maior EBITDA:           DataPro (R$ 1,710,000.00)
#
# 📊 MÉDIAS DO SETOR:
# Receita Líquida Total:    R$ 12,800,000.00
# EBITDA Total:             R$ 3,950,000.00
# Lucro Líquido Total:      R$ 3,500,000.00
# Margem Bruta Média:                 48.43%
# Margem Líquida Média:               27.53%
#
# 🏅 RANKING POR EBITDA:
# 🥇 1º - DataPro      R$ 1,710,000.00  (29.69%)
# 🥈 2º - TechCorp     R$ 1,300,000.00  (32.50%)
# 🥉 3º - CloudNet     R$   940,000.00  (30.92%)
#
# ================================================================================
# 💡 INSIGHTS ESTRATÉGICOS:
# ================================================================================
#
# TechCorp:
#   ✅ Margem líquida ACIMA da média do setor (28.75% vs 27.53%)
#   ✅ EBITDA saudável (32.50%)
#
# DataPro:
#   ⚠️  Margem líquida ABAIXO da média do setor (26.22% vs 27.53%)
#   ✅ EBITDA saudável (29.69%)
#
# CloudNet:
#   ✅ Margem líquida ACIMA da média do setor (27.63% vs 27.53%)
#   ✅ EBITDA saudável (30.92%)
# ================================================================================
